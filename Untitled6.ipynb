# %%
pip install mysql_connector_python
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import mysql.connector as ce
import pandas as pd

# %%
db = ce.connect(host = 'localhost',user = 'root',password = '12345678')

# %%
cursor  = db.cursor()

# %%
cursor.execute('show databases')

# %%
database = cursor.fetchall()

# %%
database
# Out:
# [('bank',),
#  ('csv_file',),
#  ('information_schema',),
#  ('mysql',),
#  ('performance_schema',),
#  ('sys',)]

# %%
cursor.execute('use bank')

# %%
cursor.execute('show tables')

# %%
cursor.fetchall()
# Out:
# [('bank_details',),
#  ('bonus',),
#  ('emp',),
#  ('employee',),
#  ('employeeinfo',),
#  ('employeeposition',),
#  ('empposition',),
#  ('uk-bank-customers',),
#  ('worker',),
#  ('workerclone',)]

# %%
cursor.execute('select * from employeeinfo')

# %%
data = cursor.fetchall()

# %%
data
# Out:
# [(11,
#   'Sanjay',
#   'Mehra',
#   'HR',
#   'P1',
#   'Hyderabad',
#   datetime.date(1976, 12, 1),
#   'M'),
#  (12,
#   'Ananya',
#   'Mishra',
#   'Admin',
#   'P2',
#   'Delhi',
#   datetime.date(2068, 2, 1),
#   'F'),
#  (13,
#   'Rohan',
#   'Diwan',
#   'Account',
#   'P3',
#   'MUmbai',
#   datetime.date(1980, 1, 1),
#   'M'),
#  (14,
#   'Soni',
#   'Kulkarni',
#   'HR',
#   'P1',
#   'Hyderabad',
#   datetime.date(1992, 2, 5),
#   'F'),
#  (15,
#   'Ankit',
#   'Kapoor',
#   'Admin',
#   'P2',
#   'Delhi',
#   datetime.date(1994, 7, 3),
#   'M')]

# %%
data = pd.DataFrame(data)

# %%
data
# Out:
#      0        1       2      3          4
# 0  101    rahul   kaumr  40000       tech
# 1  102    rohan  mishra  30000      sales
# 2  103    ritik   singh  35000  marketing
# 3  104    rinku   tomar  24000       tech
# 4  105   neeraj   kumar  45000   non tech
# 5  106  dheeraj   kumar  20000   non tech
# 6  107   sarita  kaumri  40000  Marketing

# %%
cursor.execute('desc employee')

# %%
col = cursor.fetchall()

# %%
col
# Out:
# [('emp_id', b'int', 'NO', 'PRI', None, ''),
#  ('first_name', b'varchar(20)', 'YES', '', None, ''),
#  ('last_name', b'varchar(20)', 'YES', '', None, ''),
#  ('salary', b'int', 'YES', '', None, ''),
#  ('Department', b'varchar(10)', 'YES', '', None, '')]

# %%
l = []
for i in col:
    l.append(i[0])

# %%
l
# Out:
# ['emp_id', 'first_name', 'last_name', 'salary', 'Department']

# %%
data.columns = l

# %%
data
# Out:
#    emp_id first_name last_name  salary Department
# 0     101      rahul     kaumr   40000       tech
# 1     102      rohan    mishra   30000      sales
# 2     103      ritik     singh   35000  marketing
# 3     104      rinku     tomar   24000       tech
# 4     105     neeraj     kumar   45000   non tech
# 5     106    dheeraj     kumar   20000   non tech
# 6     107     sarita    kaumri   40000  Marketing

# %%
df = pd.read_csv('Downloads/heart.csv')

# %%
df['sex'].value_counts()
# Out:
# 1    713
# 0    312
# Name: sex, dtype: int64

# %%
pd.crosstab(df['sex'],df['target'])
# Out:
# target    0    1
# sex
# 0        86  226
# 1       413  300

# %%
df
# Out:
#       age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0      52    1   0       125   212    0        1      168      0      1.0
# 1      53    1   0       140   203    1        0      155      1      3.1
# 2      70    1   0       145   174    0        1      125      1      2.6
# 3      61    1   0       148   203    0        1      161      0      0.0
# 4      62    0   0       138   294    1        1      106      0      1.9
# ...   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 1020   59    1   1       140   221    0        1      164      1      0.0
# 1021   60    1   0       125   258    0        0      141      1      2.8
# 1022   47    1   0       110   275    0        0      118      1      1.0
# 1023   50    0   0       110   254    0        0      159      0      0.0
# 1024   54    1   0       120   188    0        1      113      0      1.4
#
#       slope  ca  thal  target
# 0         2   2     3       0
# ...

# %%
df[['age','cp']][1020:1025]
# Out:
#       age  cp
# 1020   59   1
# 1021   60   0
# 1022   47   0
# 1023   50   0
# 1024   54   0

# %%
df[(df['target']==1) & (df['sex']==1)]
# Out:
#       age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 19     58    1   2       140   211    1        0      165      0      0.0
# 22     45    1   0       104   208    0        0      148      1      3.0
# 26     44    1   2       130   233    0        1      179      1      0.4
# 34     50    1   2       129   196    0        1      163      0      0.0
# 36     51    1   3       125   213    0        0      125      1      1.4
# ...   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 1007   56    1   3       120   193    0        0      162      0      1.9
# 1008   42    1   1       120   295    0        1      162      0      0.0
# 1011   45    1   1       128   308    0        0      170      0      0.0
# 1019   47    1   0       112   204    0        1      143      0      0.1
# 1020   59    1   1       140   221    0        1      164      1      0.0
#
#       slope  ca  thal  target
# 19        2   0     2       1
# ...

# %%
df.loc[[4,5,6,7,8,9],['age','chol','exang']]
# Out:
#    age  chol  exang
# 4   62   294      0
# 5   58   248      0
# 6   58   318      0
# 7   55   289      1
# 8   46   249      0
# 9   54   286      1

# %%
df.iloc[[5,4,5,7,8],[0,1,2,3,4]]
# Out:
#    age  sex  cp  trestbps  chol
# 5   58    0   0       100   248
# 4   62    0   0       138   294
# 5   58    0   0       100   248
# 7   55    1   0       160   289
# 8   46    1   0       120   249

# %%
df.groupby('sex').mean()
# Out:
#            age        cp    trestbps        chol       fbs   restecg  \
# sex
# 0    55.849359  1.006410  133.701923  261.455128  0.134615  0.573718
# 1    53.814867  0.914446  130.697055  239.237027  0.155680  0.510519
#
#         thalach     exang   oldpeak     slope        ca      thal    target
# sex
# 0    150.830128  0.237179  0.921154  1.410256  0.580128  2.137821  0.724359
# 1    148.363254  0.380084  1.137307  1.374474  0.830295  2.405330  0.420757

# %%
df['age'][0] = 60
# Out:
# C:\Users\LENOVO\AppData\Local\Temp/ipykernel_15168/1867782038.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['age'][0] = 60

# %%
df[df['age']>70]
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 10    71    0   0       112   149    0        1      125      0      1.6
# 99    76    0   2       140   197    0        2      116      0      1.1
# 160   77    1   0       125   304    0        0      162      1      0.0
# 162   77    1   0       125   304    0        0      162      1      0.0
# 269   71    0   2       110   265    1        0      130      0      0.0
# 285   71    0   2       110   265    1        0      130      0      0.0
# 287   71    0   1       160   302    0        1      162      0      0.4
# 313   74    0   1       120   269    0        0      121      1      0.2
# 387   77    1   0       125   304    0        0      162      1      0.0
# 401   71    0   0       112   149    0        1      125      0      1.6
# 500   71    0   0       112   149    0        1      125      0      1.6
# 535   76    0   2       140   197    0        2      116      0      1.1
# ...

# %%
for i in df['age']:
    print(i)
# Out:
# 60
# 53
# 70
# 61
# 62
# 58
# 58
# 55
# 46
# 54
# 71
# 43
# 34
# 51
# 52
# 34
# 51
# 54
# 50
# 58
# 60
# 67
# 45
# 63
# 42
# 61
# 44
# 58
# 56
# 55
# 44
# 50
# 57
# 70
# 50
# 46
# 51
# 59
# 64
# 57
# 65
# 54
# 61
# 46
# 55
# 42
# 41
# 66
# 66
# 60
# 58
# 57
# 38
# 49
# 55
# 55
# 56
# 48
# 67
# 57
# 29
# 66
# 67
# 59
# 29
# 59
# 53
# 42
# 37
# 62
# 59
# 61
# 56
# 59
# 48
# 47
# 48
# 63
# 52
# 52
# 50
# 49
# 46
# 38
# 37
# 44
# 58
# 59
# 62
# 68
# 54
# 62
# 63
# 44
# 62
# 45
# 57
# 53
# 65
# 76
# 43
# 57
# 54
# 47
# 52
# 47
# 51
# 62
# 40
# 54
# 44
# 53
# 48
# 57
# 59
# 61
# 63
# 43
# 29
# 42
# 54
# 44
# 60
# 65
# 61
# 60
# 66
# 53
# 52
# 57
# 60
# 51
# 41
# 50
# 54
# 58
# 55
# 64
# 47
# 41
# 57
# 63
# 61
# 34
# 47
# 40
# 51
# 41
# 52
# 39
# 58
# 54
# 58
# 54
# 63
# 54
# 40
# 54
# 67
# 41
# 77
# 51
# 77
# 48
# 56
# 59
# 56
# 57
# 43
# 45
# 43
# 56
# 56
# 39
# 54
# 56
# 56
# 64
# 44
# 56
# 63
# 64
# 60
# 42
# 45
# 57
# 40
# 56
# 63
# 64
# 41
# 56
# 67
# 69
# 67
# 59
# 58
# 45
# 60
# 50
# ...
